# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/real_estate_price_size.csv')

# %%
plt.scatter(df['size'],df['price'])

# %%
plt.plot(df['price'])

# %%
df.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   100 non-null    float64
#  1   size    100 non-null    float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
df.shape
# Out:
# (100, 2)

# %%
plt.hist(df['price'])
# Out:
# (array([ 7., 10., 19., 19., 17.,  8.,  8.,  6.,  4.,  2.]),
#  array([154282.128, 188922.028, 223561.928, 258201.828, 292841.728,
#         327481.628, 362121.528, 396761.428, 431401.328, 466041.228,
#         500681.128]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df['price'],height = 5,width = 5)
# Out:
# <BarContainer object of 100 artists>

# %%
X = df['size']
Y = df['price']

# %%
X.shape
# Out:
# (100,)

# %%
x1 = X.values.reshape(X.values.size,1)
x1.shape
# Out:
# (100, 1)

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(x1,Y)
# Out:
# LinearRegression()

# %%
regr.score(x1,Y)
# Out:
# 0.7447391865847586

# %%
regr.coef_
# Out:
# array([223.17874259])

# %%
regr.intercept_
# Out:
# 101912.60180122897

# %%
regr.predict([[643.09]])
# Out:
# array([245436.6193764])

# %%
y_pred = regr.predict(x1)

# %%
plt.scatter(x1,Y)
plt.plot(x1, y_pred,color = 'k')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x1,Y,random_state = 40,test_size=.2)

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
yr = regr.predict(x_test)

# %%
from sklearn.metrics import r2_score , mean_absolute_error , mean_squared_error
mae = mean_absolute_error(y_test,yr)
mse = mean_squared_error(y_test,yr)
r2s = r2_score(y_test,yr)
rmse = np.sqrt(mse)

# %%
yr
# Out:
# array([363541.48875731, 256584.3584679 , 328110.90302504, 404165.38587999,
#        256584.3584679 , 502544.94291508, 328110.90302504, 259307.49882447,
#        259307.49882447, 367155.33622505, 212850.42673033, 382001.87193959,
#        259307.49882447, 394467.51991067, 349451.73521837, 243502.23063467,
#        255646.88391891, 222641.82757529, 258506.07500369, 258506.07500369])

# %%
y_test
# Out:
# 79    342988.456
# 75    286161.600
# 63    334938.872
# 15    440201.616
# 38    292965.216
# 11    494778.992
# 40    310045.712
# 45    300061.480
# 39    245747.200
# 62    359674.440
# 86    154282.128
# 4     458674.256
# 47    201778.048
# 27    406852.304
# 81    408637.816
# 17    234178.160
# 82    190909.056
# 33    191486.896
# 9     218630.608
# 92    298170.880
# Name: price, dtype: float64

# %%
print(mae)
print(mse)
print(r2s)
print(rmse)
# Out:
# 33304.987484835
# 1547012435.3326669
# 0.8280683416803041
# 39332.07896021601
